# %% [markdown]
# # <font color='blue'>Data Science Academy - Python Fundamentos - Capítulo 9</font>
#
# ## Download: http://github.com/dsacademybr
#
# ## Mini-Projeto 2 - Análise Exploratória em Conjunto de Dados do Kaggle
#
# ## Análise 3

# %%
# Imports
import os
import subprocess
import stat
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
sns.set(style = "white")
# %matplotlib inline

# %%
# Dataset
clean_data_path = "dataset/autos.csv"
df = pd.read_csv(clean_data_path,encoding = "latin-1")

# %% [markdown]
# ## Preço médio do veículo por tipo de combustível e tipo de caixa de câmbio

# %%
# Crie um Barplot com o Preço médio do veículo por tipo de combustível e tipo de caixa de câmbio

sns.set(style="whitegrid")
g1 = sns.catplot(x='fuelType', y='price', hue='gearbox', data=df,
                height=6, aspect=1.5, kind="bar", palette="Dark2")
plt.xlabel('Tipo de Combustível', fontsize=15)
plt.ylabel('Preço Médio', fontsize=15)
plt.title('Preço médio dos veículos por combustível e caixa de câmbio', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Preço médio dos veículos por combustível e caixa de câmbio')

# %%
# Salvando o plot
fig.savefig("plots/Analise3/fueltype-vehicleType-price.png")

# %% [markdown]
# ## Potência média de um veículo por tipo de veículo e tipo de caixa de câmbio

# %%
# Crie um Barplot com a Potência média de um veículo por tipo de veículo e tipo de caixa de câmbio

sns.set(style="whitegrid")
g1 = sns.catplot(x='vehicleType', y='powerPS', hue='gearbox', data=df,
                height=6, aspect=1.5, kind="bar", palette="gist_rainbow")
plt.xlabel('Tipo de Veículo', fontsize=15)
plt.ylabel('Potência média', fontsize=15)
plt.title('Potência média dos veículos por tipo e caixa de câmbio', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Potência média dos veículos por tipo e caixa de câmbio')

# %%
# Salvando o plot
fig.savefig("plots/Analise3/vehicletype-fueltype-power.png")

# %% [markdown]
# Conheça a Formação Cientista de Dados, um programa completo, 100% online e 100% em português, com 340 horas, mais de 1.200 aulas em vídeos e 26 projetos, que vão ajudá-lo a se tornar um dos profissionais mais cobiçados do mercado de análise de dados. Clique no link abaixo, faça sua inscrição, comece hoje mesmo e aumente sua empregabilidade:
#
# https://www.datascienceacademy.com.br/pages/formacao-cientista-de-dados

# %% [markdown]
# # Fim

# %% [markdown]
# ### Obrigado - Data Science Academy - <a href="http://facebook.com/dsacademybr">facebook.com/dsacademybr</a>
